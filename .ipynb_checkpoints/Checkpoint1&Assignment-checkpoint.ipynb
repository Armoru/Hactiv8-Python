# %%
import json #assignment Answer are in last 9 Cells

# %%
with open('movies.json','r',encoding='utf-8') as file_json:
    list_data = json.load(file_json)

# %%
type(list_data)
# Out:
# list

# %%
year_dict={}
genre_dict={}

# %%
def info_list(data_list):
    arr_info = []
    list_data = data_list
    return list_data[0].keys()
print(list(info_list(list_data)))
# Out:
# ['title', 'year', 'cast', 'genres']

# %%
#check length array in dict
#for data in list_data:

# %%
#find how many movies released in a year
year_dict={}
for data in list_data:
    if data['year'] in year_dict.keys():
        year_dict[data['year']] = year_dict[data['year']]+1
    else:
        year_dict[data['year']] = 1

# %%
print (year_dict) #find how many movies released in a year
# Out:
# {1900: 17, 1901: 80, 1902: 7, 1903: 78, 1904: 25, 1905: 35, 1906: 7, 1907: 7, 1908: 18, 1909: 76, 1910: 26, 1911: 28, 1912: 44, 1913: 53, 1914: 179, 1915: 110, 1916: 144, 1917: 97, 1918: 128, 1919: 634, 1920: 129, 1921: 143, 1922: 421, 1923: 395, 1924: 480, 1925: 572, 1926: 491, 1927: 169, 1928: 437, 1929: 347, 1930: 361, 1931: 360, 1932: 408, 1933: 383, 1934: 407, 1935: 446, 1936: 504, 1937: 473, 1938: 423, 1939: 339, 1940: 385, 1941: 358, 1942: 359, 1943: 465, 1944: 456, 1945: 415, 1946: 423, 1947: 390, 1948: 421, 1949: 351, 1950: 443, 1951: 429, 1952: 374, 1953: 366, 1954: 251, 1955: 268, 1956: 300, 1957: 335, 1958: 281, 1959: 205, 1960: 162, 1961: 150, 1962: 144, 1963: 140, 1964: 151, 1965: 129, 1966: 131, 1967: 127, 1968: 143, 1969: 137, 1970: 137, 1971: 145, 1972: 140, 1973: 142, 1974: 142, 1975: 128, 1976: 149, 1977: 131, 1978: 134, 1979: 139, 1980: 182, 1981: 140, 1982: 142, 1983: 140, 1984: 167, 1985: 187, 1986: 192, 1987: 283, 1988: 292, 1989: 261, 1990: 269, 1991: 202, 1992: 224, 1993: 204, 1994: 292, 1995: 307, 1996: 363, 1997: 362, 1998: 242, 1999: 221, 2000: 213, 2001: 226, 2002: 232, 2003: 221, 2004: 239, 2005: 228, 2006: 425, 2007: 304, 2008: 206, 2009: 229, 2010: 210, 2011: 201, 2012: 295, 2013: 376, 2014: 214, 2015: 130, 2016: 143, 2017: 238, 2018: 236}

# %%
#find how many genre released all time
genre_dict={}
for data in list_data:
    if len(data['genres']) ==0:
        if 'Unknown' in genre_dict.keys():
            genre_dict['Unknown'] = genre_dict['Unknown'] +1
        else:
            genre_dict['Unknown'] = 1
    else:
        for g_data in data['genres']:         
            if g_data in genre_dict.keys():
                genre_dict[g_data] = genre_dict[g_data] +1
            else:
                genre_dict[g_data] = 1

# %%
print (genre_dict) #find how many movies released in a genre
# Out:
# {'Unknown': 901, 'Short': 355, 'Documentary': 529, 'Comedy': 7363, 'Western': 3013, 'Adventure': 999, 'Romance': 1147, 'Crime': 1499, 'Drama': 8744, 'Action': 1109, 'Animated': 757, 'Historical': 106, 'Biography': 439, 'Horror': 1166, 'Fantasy': 327, 'Silent': 7, 'Sports': 139, 'Thriller': 865, 'War': 556, 'Mystery': 629, 'Erotic': 36, 'Spy': 71, 'Family': 381, 'Science Fiction': 780, 'Musical': 1166, 'Sport': 8, 'Noir': 403, 'Suspense': 111, 'Live Action': 9, 'Disaster': 32, 'Teen': 21, 'Political': 14, 'Satire': 58, 'Slasher': 15, 'Martial Arts': 21, 'Performance': 22, 'Superhero': 83, 'Independent': 2, 'Dance': 14, 'Supernatural': 11, 'Legal': 1, 'Found Footage': 1}

# %%
#total movies
def total_movies(data_list):
    list_data = data_list
    count=0
    for data in list_data:
        count = count+1

    return count

# %%
#check total movies from year
count = 0
for data in year_dict.keys():
    count = count + year_dict[data]
print(count)
# Out:
# 28795

# %%
count = 0
for data in genre_dict.keys():
    count = count + genre_dict[data]
print(count)
# Out:
# 33910

# %%
year = input('What year you want to see?\n')
# Out:
# What year you want to see?
# 1995

# %%
def drill_year(year):
    int_year = int(year)
    year_dict={}
    for data in list_data:
        if data['year'] in year_dict.keys():
            year_dict[data['year']] = year_dict[data['year']]+1
        else:
            year_dict[data['year']] = 1
    return year_dict[int_year]

# %%
year = input('What year you want to see?\n')

try:
    print("Movies released in %s are %s movies" %(year,drill_year(year)))
except KeyError:
    print("Movies released in %s is not found"%(year))
# Out:
# What year you want to see?
# 1995
# Movies released in 1995 are 307 movies

# %%
def drill_genre(genre):
    get_genre = str(genre)
    genre_dict={}
    for data in list_data:
        if len(data['genres']) ==0:
            if 'Unknown' in genre_dict.keys():
                genre_dict['Unknown'] = genre_dict['Unknown'] +1
            else:
                genre_dict['Unknown'] = 1
        else:
            for g_data in data['genres']:
                if g_data in genre_dict.keys():
                    genre_dict[g_data] = genre_dict[g_data] +1
                else:
                    genre_dict[g_data] = 1
    return genre_dict[get_genre]

# %%
genre= input('What genre you want to see?\n')
try:
    print("Movies released in %s are %s movies" %(genre,drill_genre(genre)))
except KeyError:
    print("Movies released in %s is not found"%(genre))
# Out:
# What genre you want to see?
# Horror
# Movies released in Horror are 1166 movies

# %%
set_year = set()
for data in year_dict.keys():
    set_year.add(data)

# %%
print(set_year)
# Out:
# {1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018}

# %%
print(list(set_year)[0]) #earliest movie year
# Out:
# 1900

# %%
print(list(set_year)[len(set_year)-1]) #lastest movie year
# Out:
# 2018

# %%
max_movie_genre = 0
key_genre = ''
for data in genre_dict.keys():
    if max_movie_genre < genre_dict[data]:
        max_movie_genre = genre_dict[data]
        key_genre = data
print ("%s : %s"%(key_genre,max_movie_genre)) #max movie genre
# Out:
# Drama : 8744

# %%
#find how many cast
cast_dict={}
for data in list_data:
    if len(data['cast']) ==0:
        if 'Unknown' in cast_dict.keys():
            cast_dict['Unknown'] = cast_dict['Unknown'] +1
        else:
            cast_dict['Unknown'] = 1
    else:
        for g_data in data['cast']:         
            if g_data in cast_dict.keys():
                cast_dict[g_data] = cast_dict[g_data] +1
            else:
                cast_dict[g_data] = 1

# %%
print (cast_dict) #total cast
# Out:
# {'Unknown': 925, 'Paul Boyton': 1, 'Ching Ling Foo': 1, 'May Clark': 1, 'William Carrington': 1, 'J. Stuart Blackton': 2, 'Florence Lawrence': 8, 'William S. Hart': 14, 'William Craven': 1, 'Bertha Regustus': 1, 'Edward Boulden': 1, 'Arthur V. Johnson': 8, 'Linda Arvidson': 5, 'William V. Ranous': 3, 'George Gebhardt': 4, 'Charles Inslee': 6, 'D. W. Griffith': 2, 'Harry Solter': 5, 'Tom Ricketts': 2, 'Edward Dillon': 2, 'Hobart Bosworth': 20, 'Betty Harte': 1, 'Florence Auer': 2, 'John G. Adolfi': 1, 'Paul Panzer': 4, 'John Tansey': 1, 'Marion Leonard': 6, 'Owen Moore': 30, 'Mack Sennett': 7, "Barry O'Moore": 1, 'John R. Cumpson': 2, 'Anita Hendrie': 1, 'Leopold Wharton': 1, 'Mary Pickford': 40, 'George Nichols': 5, 'Gladys Egan': 1, 'Marc McDermott': 3, 'Charles Stanton Ogle': 2, 'Robert Z. Leonard': 4, 'Charles Craig': 1, 'Augustus Phillips': 1, 'Mary Fuller': 2, 'Kate Bruce': 1, 'Harry Carey': 61, 'Henry B. Walthall': 31, 'Frank Powell': 2, 'Charles West': 1, 'Sidney Olcott': 1, 'Gene Gauntier': 1, "Thomas O'Connor": 1, 'Anna Rosemond': 1, 'George Barnes': 1, 'Frank H. Crane': 1, 'Tom Mix': 71, 'Stephanie Longfellow': 1, 'Theodore Roosevelt': 1, 'Fatty Arbuckle': 30, 'Clara T. Bracy': 1, 'Billy Quirk': 1, 'Bebe Daniels': 103, 'William Garwood': 71, 'Marguerite Snow': 7, 'Charles Ogle': 1, 'Natalie Jerome': 1, 'Edgar G. Wynn': 1, 'Marie Eline': 6, 'Alan Hale': 24, 'Mabel Normand': 32, 'Harry Hyde': 1, 'James Cruze': 8, 'Florence La Badie': 6, 'Mignon Anderson': 7, 'William Russell': 38, 'Wilfred Lucas': 15, 'Joseph Graybill': 1, 'Herbert Rawlinson': 34, 'H. B. Irving': 1, 'Alice Young': 1, 'King Baggot': 4, 'Lucille Young': 1, 'Maurice Costello': 5, 'Florence Turner': 2, 'Bertha Blanchard': 1, 'Dorothy Bernard': 2, 'Edwin August': 2, 'Dorothy Kelly': 1, 'Leah Baird': 6, 'Harry Benham': 3, 'Jean Darnell': 3, 'Harry von Meter': 27, 'Vivian Rich': 23, 'Tom Moore': 30, 'Alice Joyce': 25, 'Earle Foxe': 32, 'James Gordon': 1, 'Richard Neill': 1, 'Riley Chamberlin': 2, 'Ethel Wright': 2, '.': 32, 'Francis Ford': 8, 'Ethel Grandin': 2, 'Blanche Sweet': 29, 'Charles Hill Mailes': 2, 'Robert Henderson-Bland': 1, 'George Beech': 1, 'Wallace Reid': 26, 'Dorothy Davenport': 4, 'Charlotte Burton': 54, 'Martin Fuller': 1, 'Mrs. William Bechtel': 1, 'Walter Edwin': 1, 'Bigelow Cooper': 2, 'Frank Hall Crane': 1, 'Rodman Law': 1, 'Elmer Booth': 1, 'Lillian Gish': 34, 'Lionel Barrymore': 83, 'W. Chrystie Miller': 1, 'Eugenie Forde': 2, 'Dorothy Gibson': 1, 'Riley Chamberlain': 1, 'Hazel Neason': 1, 'Stuart Holmes': 11, 'David Thompson': 1, 'Dorothy Gish': 21, 'Lee Moran': 4, 'Russell Bassett': 1, 'Louise Glaum': 14, 'Kathlyn Williams': 5, 'Sydney Ayres': 16, 'Charles Cummings': 1, 'Victory Bateman': 2, 'Howard Davies': 2, 'J. Warren Kerrigan': 15, 'Pauline Bush': 7, 'Ford Sterling': 16, 'Barney Oldfield': 1, 'James Young': 1, 'Clara Kimball Young': 11, 'George Cooper': 3, 'Murdock MacQuarrie': 4, 'Jean Acker': 4, 'Louise Lester': 27, 'Fred Mace': 1, 'Alie Hollister': 1, 'Robert G. Vignola': 1, 'Helen Lidroth': 1, 'Miriam Cooper': 9, 'Irene Boyle': 3, 'Helen Armstrong': 2, 'Mona Darkfeather': 2, 'Mabel Brown': 1, 'Edward Coxen': 13, 'Charles Bartlett': 1, 'Harold Lloyd': 190, 'Ben F. Wilson': 3, 'Alexander Gaden': 1, 'Edna Maison': 1, 'Margarita Fischer': 7, 'Mae Marsh': 23, 'Claire McDowell': 5, 'Matt Moore': 30, 'Jean Durrell': 2, 'Carey L. Hastings': 1, 'Ernest C. Warde': 1, 'Muriel Ostriche': 2, 'George Field': 11, 'Winifred Greenwood': 4, 'John Steppling': 5, 'Caroline Frances Cooke': 4, 'Jack Richardson': 17, 'Herbert Tracey': 1, 'Royal Byron': 1, 'Eloise Willard': 1, 'Mabel Paige': 3, 'Oliver Hardy': 30, 'J. Barney Sherry': 2, 'Clara Williams': 3, 'Donald Crisp': 21, 'Lilian Gish': 2, 'Charlie Chaplin': 54, 'Chester Conklin': 11, 'George Larkin': 4, 'B. Reeves Eason': 6, 'Edward Abeles': 2, 'Sydney Deane': 1, 'Joseph Singleton': 1, 'Robert Harron': 8, 'William J. Butler': 1, 'Mack Swain': 5, 'Phyllis Allen': 6, 'Edith Borella': 10, 'Ida  ...

# %%
#find how max cast in  years
max_cast = 0
key_cast = ''
for data in cast_dict.keys():
    if data != 'Unknown':
        if max_cast < cast_dict[data]:
            max_cast = cast_dict[data]
            key_cast = data
print ("%s : %s"%(key_cast,max_cast)) #max cast : movie
#print(cast_dict.keys())
# Out:
# Harold Lloyd : 190

# %%
#How many movies are in the json files?
print("How many movies are in the json files?\n%s" %(total_movies(list_data)))
# Out:
# How many movies are in the json files?
# 28795

# %%
#What kind of information stored in the data?
print("What kind of information stored in the data?\n%s"%(list(info_list(list_data))))
# Out:
# What kind of information stored in the data?
# ['title', 'year', 'cast', 'genres']

# %%
#count total distinct genre and list
genre_count=0
for data in genre_dict.keys():
    genre_count = genre_count +1

# %%
#How many distinct genres are there? What are they?

print("How many distinct genres are there?\n%s \nWhat are they?\n%s"%(genre_count, list(genre_dict.keys())))
# Out:
# How many distinct genres are there?
# 42
# What are they?
# ['Unknown', 'Short', 'Documentary', 'Comedy', 'Western', 'Adventure', 'Romance', 'Crime', 'Drama', 'Action', 'Animated', 'Historical', 'Biography', 'Horror', 'Fantasy', 'Silent', 'Sports', 'Thriller', 'War', 'Mystery', 'Erotic', 'Spy', 'Family', 'Science Fiction', 'Musical', 'Sport', 'Noir', 'Suspense', 'Live Action', 'Disaster', 'Teen', 'Political', 'Satire', 'Slasher', 'Martial Arts', 'Performance', 'Superhero', 'Independent', 'Dance', 'Supernatural', 'Legal', 'Found Footage']

# %%
#Movie’s year? Earliest & Latest?
print("Movie’s year Earliest is \n%s \nLatest?\n%s" %(list(set_year)[0],list(set_year)[len(set_year)-1]))
# Out:
# Movie’s year Earliest is
# 1900
# Latest?
# 2018

# %%
#How many movies each year?
print("How many movies each year?\n")
for data in year_dict.keys():
    print ("In %s : %s Movies"%(data,year_dict[data]))
# Out:
# How many movies each year?
#
# In 1900 : 17 Movies
# In 1901 : 80 Movies
# In 1902 : 7 Movies
# In 1903 : 78 Movies
# In 1904 : 25 Movies
# In 1905 : 35 Movies
# In 1906 : 7 Movies
# In 1907 : 7 Movies
# In 1908 : 18 Movies
# In 1909 : 76 Movies
# In 1910 : 26 Movies
# In 1911 : 28 Movies
# In 1912 : 44 Movies
# In 1913 : 53 Movies
# In 1914 : 179 Movies
# In 1915 : 110 Movies
# In 1916 : 144 Movies
# In 1917 : 97 Movies
# In 1918 : 128 Movies
# In 1919 : 634 Movies
# In 1920 : 129 Movies
# In 1921 : 143 Movies
# In 1922 : 421 Movies
# In 1923 : 395 Movies
# In 1924 : 480 Movies
# In 1925 : 572 Movies
# In 1926 : 491 Movies
# In 1927 : 169 Movies
# In 1928 : 437 Movies
# In 1929 : 347 Movies
# In 1930 : 361 Movies
# In 1931 : 360 Movies
# In 1932 : 408 Movies
# In 1933 : 383 Movies
# In 1934 : 407 Movies
# In 1935 : 446 Movies
# In 1936 : 504 Movies
# In 1937 : 473 Movies
# In 1938 : 423 Movies
# In 1939 : 339 Movies
# In 1940 : 385 Movies
# In 1941 : 358 Movies
# In 1942 : 359 Movies
# In 1943 : 465 Movies
# In 1944 : 456 Movies
# In 1945 : 415 Movies
# In 1946 : 423 Movies
# In 1947 : 390 Movies
# In 1948 : 421 Movies
# In 1949 : 351 Movies
# In 1950 : 443 Movies
# In 1951 : 429 Movies
# In 1952 : 374 Movies
# In 1953 : 366 Movies
# In 1954 : 251 Movies
# In 1955 : 268 Movies
# In 1956 : 300 Movies
# In 1957 : 335 Movies
# In 1958 : 281 Movies
# In 1959 : 205 Movies
# In 1960 : 162 Movies
# In 1961 : 150 Movies
# In 1962 : 144 Movies
# In 1963 : 140 Movies
# In 1964 : 151 Movies
# In 1965 : 129 Movies
# In 1966 : 131 Movies
# In 1967 : 127 Movies
# In 1968 : 143 Movies
# In 1969 : 137 Movies
# In 1970 : 137 Movies
# In 1971 : 145 Movies
# In 1972 : 140 Movies
# In 1973 : 142 Movies
# In 1974 : 142 Movies
# In 1975 : 128 Movies
# In 1976 : 149 Movies
# In 1977 : 131 Movies
# In 1978 : 134 Movies
# In 1979 : 139 Movies
# In 1980 : 182 Movies
# In 1981 : 140 Movies
# In 1982 : 142 Movies
# In 1983 : 140 Movies
# In 1984 : 167 Movies
# In 1985 : 187 Movies
# In 1986 : 192 Movies
# In 1987 : 283 Movies
# In 1988 : 292 Movies
# In 1989 : 261 Movies
# In 1990 : 269 Movies
# In 1991 : 202 Movies
# In 1992 : 224 Movies
# In 1993 : 204 Movies
# In 1994 : 292 Movies
# In 1995 : 307 Movies
# In 1996 : 363 Movies
# In 1997 : 362 Movies
# In 1998 : 242 Movies
# In 1999 : 221 Movies
# In 2000 : 213 Movies
# In 2001 : 226 Movies
# In 2002 : 232 Movies
# In 2003 : 221 Movies
# In 2004 : 239 Movies
# In 2005 : 228 Movies
# In 2006 : 425 Movies
# In 2007 : 304 Movies
# In 2008 : 206 Movies
# In 2009 : 229 Movies
# In 2010 : 210 Movies
# In 2011 : 201 Movies
# In 2012 : 295 Movies
# In 2013 : 376 Movies
# In 2014 : 214 Movies
# In 2015 : 130 Movies
# In 2016 : 143 Movies
# In 2017 : 238 Movies
# In 2018 : 236 Movies

# %%
#How many movies in each genre?
print("How many movies in each genre?\n")
for data in genre_dict.keys():
    print("In %s : %s Movies"%(data,genre_dict[data]))
# Out:
# How many movies in each genre?
#
# In Unknown : 901 Movies
# In Short : 355 Movies
# In Documentary : 529 Movies
# In Comedy : 7363 Movies
# In Western : 3013 Movies
# In Adventure : 999 Movies
# In Romance : 1147 Movies
# In Crime : 1499 Movies
# In Drama : 8744 Movies
# In Action : 1109 Movies
# In Animated : 757 Movies
# In Historical : 106 Movies
# In Biography : 439 Movies
# In Horror : 1166 Movies
# In Fantasy : 327 Movies
# In Silent : 7 Movies
# In Sports : 139 Movies
# In Thriller : 865 Movies
# In War : 556 Movies
# In Mystery : 629 Movies
# In Erotic : 36 Movies
# In Spy : 71 Movies
# In Family : 381 Movies
# In Science Fiction : 780 Movies
# In Musical : 1166 Movies
# In Sport : 8 Movies
# In Noir : 403 Movies
# In Suspense : 111 Movies
# In Live Action : 9 Movies
# In Disaster : 32 Movies
# In Teen : 21 Movies
# In Political : 14 Movies
# In Satire : 58 Movies
# In Slasher : 15 Movies
# In Martial Arts : 21 Movies
# In Performance : 22 Movies
# In Superhero : 83 Movies
# In Independent : 2 Movies
# In Dance : 14 Movies
# In Supernatural : 11 Movies
# In Legal : 1 Movies
# In Found Footage : 1 Movies

# %%
#What is the genre with most movies?

print ("What is the genre with most movies?\n%s : %s"%(key_genre,max_movie_genre))
# Out:
# What is the genre with most movies?
# Drama : 8744

# %%
#count cast
cast_count=0
for data in cast_dict.keys():
    cast_count = cast_count +1

# %%
#How many cast are there?
print("How many cast are there?\n%s Actor/Actress"%(cast_count))
# Out:
# How many cast are there?
# 15531 Actor/Actress

# %%
#Who are the actor/actress played most movies over years?
print("Who are the actor/actress played most movies over years?\n%s : %s"%(key_cast,max_cast))
# Out:
# Who are the actor/actress played most movies over years?
# Harold Lloyd : 190
